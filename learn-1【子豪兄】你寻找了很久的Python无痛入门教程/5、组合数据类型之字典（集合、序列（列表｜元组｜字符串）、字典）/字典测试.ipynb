# %%
d={'中国':'北京','美国':'华盛顿','日本':'东京'}
type(d)
# Out:
# dict

# %%
d['日本']
# Out:
# '东京'

# %%
d['俄罗斯'] = '莫斯科'
d
# Out:
# {'中国': '北京', '美国': '华盛顿', '日本': '东京', '俄罗斯': '莫斯科'}

# %%
d[985] = 211
d
# Out:
# {'中国': '北京', '美国': '华盛顿', '日本': '东京', '俄罗斯': '莫斯科', 985: 211}

# %%
d[985]
# Out:
# 211

# %% [markdown]
# 字典的操作函数和方法

# %%
d.keys()
# Out:
# dict_keys(['中国', '美国', '日本', '俄罗斯', 985])

# %%
for key in d.keys():
    print(key)
# Out:
# 中国
# 美国
# 日本
# 俄罗斯
# 985

# %%
d.values()
# Out:
# dict_values(['北京', '华盛顿', '东京', '莫斯科', 211])

# %%
d.items()
# Out:
# dict_items([('中国', '北京'), ('美国', '华盛顿'), ('日本', '东京'), ('俄罗斯', '莫斯科'), (985, 211)])

# %%
d.get('中国')
# Out:
# '北京'

# %%
d.pop('中国')
# Out:
# '北京'

# %%
# 随机删除一个键值对,以元组的形式返回
d.popitem()
# Out:
# (985, 211)

# %% [markdown]
# img.png
